# %%
# importing important libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ydata_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10608\2817273545.py in <module>
#       4 import matplotlib.pyplot as plt
#       5 import seaborn as sns
# ----> 6 from ydata_profiling import ProfileReport
#
# ~\anaconda3\lib\site-packages\ydata_profiling\__init__.py in <module>
#      12 import importlib.util  # isort:skip # noqa
#      13
# ---> 14 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      15 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      16 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# ~\anaconda3\lib\site-packages\ydata_profiling\compare_reports.py in <module>
#      10 from ydata_profiling.model import BaseDescription
#      11 from ydata_profiling.model.alerts import Alert
# ---> 12 from ydata_profiling.profile_report import ProfileReport
#      13
#      14
#
# ~\anaconda3\lib\site-packages\ydata_profiling\profile_report.py in <module>
#      17 import pandas as pd
#      18 from tqdm.auto import tqdm
# ---> 19 from typeguard import typechecked
#      20 from visions import VisionsTypeset
#      21
#
# ~\anaconda3\lib\site-packages\typeguard\__init__.py in <module>
#       2 from typing import Any
#       3
# ----> 4 from ._checkers import TypeCheckerCallable as TypeCheckerCallable
#       5 from ._checkers import TypeCheckLookupCallback as TypeCheckLookupCallback
#       6 from ._checkers import check_type_internal as check_type_internal
#
# ~\anaconda3\lib\site-packages\typeguard\_checkers.py in <module>
#      64         is_typeddict,
#      65     )
# ---> 66     from typing_extensions import Any as SubclassableAny
#      67
#      68 if sys.version_info >= (3, 10):
#
# ImportError: cannot import name 'Any' from 'typing_extensions' (C:\Users\ankit\anaconda3\lib\site-packages\typing_extensions.py)

# %%
crime_data = pd.read_csv("Crime_Data_from_2020_to_Present.csv")
crime_data.head() # uploading data into data frame.
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0   10304468              01-08-2020              01-08-2020      2230     3
# 1  190101086              01-02-2020              01-01-2020       330     1
# 2  200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200     1
# 3  191501505              01-01-2020              01-01-2020      1730    15
# 4  191921269              01-01-2020              01-01-2020       415    19
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Southwest          377         2     624
# 1      Central          163         2     624
# 2      Central          155         2     845
# 3  N Hollywood         1543         2     745
# 4      Mission         1998         2     740
#
#                                          Crm Cd Desc  ... Status  \
# 0                           BATTERY - SIMPLE ASSAULT  ...     AO
# 1                           BATTERY - SIMPLE ASSAULT  ...     IC
# 2          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE  ...     AA
# 3           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
# 4  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
#
#     Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0   Adult Other    624.0      NaN       NaN      NaN
# 1   Invest Cont    624.0      NaN       NaN      NaN
# 2  Adult Arrest    845.0      NaN       NaN      NaN
# 3   Invest Cont    745.0    998.0       NaN      NaN
# 4   Invest Cont    740.0      NaN       NaN      NaN
#
#                                    LOCATION Cross Street      LAT       LON
# 0   1100 W  39TH                         PL          NaN  34.0141 -118.2978
# 1    700 S  HILL                         ST          NaN  34.0459 -118.2545
# 2    200 E  6TH                          ST          NaN  34.0448 -118.2474
# 3   5400    CORTEEN                      PL          NaN  34.1685 -118.4019
# 4  14400    TITUS                        ST          NaN  34.2198 -118.4468
#
# [5 rows x 28 columns]

# %%
crime_data.isna().sum() # checking for na values
# Out:
# DR_NO                  0
# Date Rptd              0
# DATE OCC               0
# TIME OCC               0
# AREA                   0
# AREA NAME              0
# Rpt Dist No            0
# Part 1-2               0
# Crm Cd                 0
# Crm Cd Desc            0
# Mocodes           114148
# Vict Age               0
# Vict Sex          108529
# Vict Descent      108537
# Premis Cd             10
# Premis Desc          488
# Weapon Used Cd    537498
# Weapon Desc       537498
# Status                 0
# Status Desc            0
# Crm Cd 1              10
# Crm Cd 2          764505
# Crm Cd 3          823173
# Crm Cd 4          825151
# LOCATION               0
# Cross Street      693343
# LAT                    0
# LON                    0
# dtype: int64

# %%
column_seperate=["Mocodes","Vict Descent","Vict Sex","Weapon Used Cd","Weapon Desc","Cross Street","Crm Cd 1","Crm Cd 2","Crm Cd 3","Crm Cd 4"]
# separating columns with high na values to secondary data frame. (maybe they can be used at somepoint during project)

# %%
crime_data_1 = crime_data.drop(columns = column_seperate) # data frame with columns most appropriate at this point.
# we may need to change them as we advance further.

# %%
crime_data_1.isna().sum() # checking na with new df.
# Out:
# DR_NO            0
# Date Rptd        0
# DATE OCC         0
# TIME OCC         0
# AREA             0
# AREA NAME        0
# Rpt Dist No      0
# Part 1-2         0
# Crm Cd           0
# Crm Cd Desc      0
# Vict Age         0
# Premis Cd       10
# Premis Desc    488
# Status           0
# Status Desc      0
# LOCATION         0
# LAT              0
# LON              0
# dtype: int64

# %%
crime_data_1["Premis Desc"].fillna("unknown", inplace = True)

# %%
crime_data_1 = crime_data_1.dropna(subset=["Premis Cd"])

# %%
crime_data_1.isna().sum() # df with zero na
# Out:
# DR_NO          0
# Date Rptd      0
# DATE OCC       0
# TIME OCC       0
# AREA           0
# AREA NAME      0
# Rpt Dist No    0
# Part 1-2       0
# Crm Cd         0
# Crm Cd Desc    0
# Vict Age       0
# Premis Cd      0
# Premis Desc    0
# Status         0
# Status Desc    0
# LOCATION       0
# LAT            0
# LON            0
# dtype: int64

# %%
crime_data_1 # looking into data with no na
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0        10304468              01-08-2020              01-08-2020      2230
# 1       190101086              01-02-2020              01-01-2020       330
# 2       200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200
# 3       191501505              01-01-2020              01-01-2020      1730
# 4       191921269              01-01-2020              01-01-2020       415
# ...           ...                     ...                     ...       ...
# 825207  231604807  01/27/2023 12:00:00 AM  01/26/2023 12:00:00 AM      1800
# 825208  231606525  03/22/2023 12:00:00 AM  03/22/2023 12:00:00 AM      1000
# 825209  231210064              04-12-2023              04-12-2023      1630
# 825210  230115220              07-02-2023              07-01-2023         1
# 825211  230906458              03-05-2023              03-05-2023       900
#
#         AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0          3    Southwest          377         2     624
# 1          1      Central          163         2     624
# 2          1      Central          155         2     845
# 3         15  N Hollywood         1543         2     745
# 4         19      Mission         1998         2     740
# ...      ...          ...          ...       ...     ...
# 825207    16     Foothill         1663         2     740
# 825208    16     Foothill         1602         1     230
# 825209    12  77th Street         1239         1     230
# 825210     1      Central          154         1     352
# 825211     9     Van Nuys          914         2     745
#
#                                               Crm Cd Desc  Vict Age  \
# 0                                BATTERY - SIMPLE ASSAULT        36
# 1                                BATTERY - SIMPLE ASSAULT        25
# 2               SEX OFFENDER REGISTRANT OUT OF COMPLIANCE         0
# 3                VANDALISM - MISDEAMEANOR ($399 OR UNDER)        76
# 4       VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...        31
# ...                                                   ...       ...
# 825207  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...        23
# 825208     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        25
# 825209     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        29
# 825210                                         PICKPOCKET        24
# 825211           VANDALISM - MISDEAMEANOR ($399 OR UNDER)        53
#
#         Premis Cd                                   Premis Desc Status  \
# 0           501.0                        SINGLE FAMILY DWELLING     AO
# 1           102.0                                      SIDEWALK     IC
# 2           726.0                               POLICE FACILITY     AA
# 3           502.0  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)     IC
# 4           409.0                           BEAUTY SUPPLY STORE     IC
# ...           ...                                           ...    ...
# 825207      122.0                      VEHICLE, PASSENGER/TRUCK     IC
# 825208      102.0                                      SIDEWALK     IC
# 825209      222.0                                    LAUNDROMAT     IC
# 825210      735.0               NIGHT CLUB (OPEN EVENINGS ONLY)     IC
# 825211      502.0  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)     IC
#
#          Status Desc                                  LOCATION      LAT  \
# 0        Adult Other   1100 W  39TH                         PL  34.0141
# 1        Invest Cont    700 S  HILL                         ST  34.0459
# 2       Adult Arrest    200 E  6TH                          ST  34.0448
# 3        Invest Cont   5400    CORTEEN                      PL  34.1685
# 4        Invest Cont  14400    TITUS                        ST  34.2198
# ...              ...                                       ...      ...
# 825207   Invest Cont  12500    BRANFORD                     ST  34.2466
# 825208   Invest Cont  12800    FILMORE                      ST  34.2790
# 825209   Invest Cont   6100 S  VERMONT                      AV  33.9841
# 825210   Invest Cont    500 S  MAIN                         ST  34.0467
# 825211   Invest Cont  14500    HARTLAND                     ST  34.1951
#
#              LON
# 0      -118.2978
# 1      -118.2545
# 2      -118.2474
# 3      -118.4019
# 4      -118.4468
# ...          ...
# 825207 -118.4054
# 825208 -118.4116
# 825209 -118.2915
# 825210 -118.2485
# 825211 -118.4487
#
# [825202 rows x 18 columns]

# %%
pr_df1 = ProfileReport(crime_data_1)
pr_df1 # trying something new........ydata_profiling.
#  it hepls to draw lot of insights from data....everything for EDA at one place.
# can be of
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19216\3819627192.py in <module>
# ----> 1 pr_df1 = ProfileReport(crime_data_1)
#       2 pr_df1 # trying something new........ydata_profiling.
#       3 #  it hepls to draw lot of insights from data....everything for EDA at one place.
#       4 # can be of
#
# NameError: name 'ProfileReport' is not defined
